# %%
# !pip install pandas

# %%
import pandas as pd

d1 = {
    'names' : ['Kaladin', 'Shallan', 'Dalinar', 'Szeth'],
    'groups' : ['Windrunner', 'Lightweaver', 'Bondsmith', 'Skybreaker'],
    'ranks' : [10, 9, 10, 8],
    'can fly': [True, False, False, True]
}
df = pd.DataFrame(d1)
df

# %%
# Create DataFrame from dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [20, 21, 19, 22],
    'Grade': [85, 78, 92, 88]
}

df2 = pd.DataFrame(data)
df2

# %%
df.dtypes

# %%
df

# %%
df.info()

# %%
df3 = pd.read_csv('data.csv')
df3

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Age': [20, 21, 19, 22, 20],
    'Grade': [85, 78, 92, 88, 75],
    'City': ['Mumbai', 'Delhi', 'Mumbai', 'Bangalore', 'Delhi']
}

df4 = pd.DataFrame(data)
df4

# %%
# Basic information
print(df4.shape)          # (5, 4) - 5 rows, 4 columns
print(df4.columns)        # Column names
print(df4.index)          # Row indices
print(len(df4))           # Number of rows

# %%
df.info()

# %%
df4.describe()

# %%
df.describe(include='object')

# %%
df.describe(include='bool')

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
df5

# %%
df6 = pd.read_csv('https://gist.githubusercontent.com/slopp/ce3b90b9168f2f921784de84fa445651/raw/4ecf3041f0ed4913e7c230758733948bc561f434/penguins.csv')
df6

# %%
df5.info()

# %%
df5.head()

# %%
df6.tail()

# %%
df6['species']

# %%
df6['species'].value_counts()

# %%
df6['island'].value_counts()

# %%
df6['species'].value_counts().plot(kind='pie', autopct='%.1f%%')

# %%
df6[['body_mass_g', 'flipper_length_mm']].describe()

# %%
df6[['body_mass_g', 'flipper_length_mm']].plot(
    kind='scatter', 
    x='flipper_length_mm', 
    y='body_mass_g')

# %%
df5['Age'] <= 18 # filter

# %%
df5[df5['Age'] <= 18]

# %%
df5['Survived'].value_counts()

# %%
df5[df5['Age'] > 18]['Survived'].value_counts()

# %%
df5[df5['Age'] > 18]['Sex'].value_counts()

# %%
df5[df5['Age'] > 18]['Sex'].value_counts().plot(kind='bar')
